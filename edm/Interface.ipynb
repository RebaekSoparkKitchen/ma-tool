# %%
# %run Exe.py
# Out:
# I import the third party module using 0.0 seconds.
# I run this program using 0.13494443893432617 seconds.
# Future work
#                               Campaign Name                 Owner   \
# 0               GB_企业上市融资主题webinar_Apr28_W2        Lily Li/I072293
# 1                    HK_Ariba Sourcing - IT  Cheung Helen/C5273583
# 2  HK_SME Continuity - Supply Chain_nurture  Cheung Helen/C5273583
# 3                    Sol_Opentext_EDM_April   April Hsiung/I312577
# 4                          CX_3rd会邀_Sunqian               Sun Qian
# 5                  GB_企业出海白皮书发布webinar_May8        Lily Li/I072293
# 6               GB_企业出海白皮书发布webinar_May8_W2        Lily Li/I072293
#
#   Launch Date weekday
# 0  2020-04-27     星期一
# 1  2020-04-28     星期二
# 2  2020-04-28     星期二
# 3  2020-04-28     星期二
# 4  2020-04-29     星期三
# 5  2020-04-30     星期四
# 6  2020-05-07     星期四
# Wait work
#                                          Campaign Name                 Owner   \
# ...
