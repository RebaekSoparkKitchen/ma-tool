# %%
# %run Exe.py
# Out:
# I import the third party module using 1.6573731899261475 seconds.
# I run this program using 0.12961626052856445 seconds.
# Future work
#                                        Campaign Name                 Owner   \
# 0                              GB_金融webinar_ZulinMao              Zulin Mao
# 1                              CX_AR_webinar_sunqian               Sun Qian
# 2                           GB_金融webinar_ZulinMao_W2              Zulin Mao
# 3                           Sol_Auto_DSC_webinar_Ivy       Tan, Ivy/I344787
# 4  HK_Nurture: Ariba Sourcing - IT + Supply Chain...  Cheung Helen/C5273583
# 5  HK_Nurture: Ariba Sourcing - Procurement & Fin...  Cheung Helen/C5273583
# 6                             Sol_HT_DSC_webinar_Ivy       Tan, Ivy/I344787
# 7                            DBS_S4HANA项目经验大揭秘_Daisi            DaiSi Huang
# 8         HK_Digital Workforce Webianr - SF + Concur  Cheung Helen/C5273583
#
#   Launch Date weekday
# 0  2020-04-08     星期三
# 1  2020-04-09     星期四
# ...
