# %%
# %run Exe.py
# Out:
# I import the third party module using 0.0 seconds.
# I run this program using 0.17058467864990234 seconds.
# Future work
#                                        Campaign Name                 Owner   \
# 0                   DG_SAP助您共克疫情 | 制造企业分析及建议_chenzhu               Zhu Chen
# 1                           CX_中国芯webinar_sunqian_W2               Sun Qian
# 2     HK_ Simplifying Invoice and Expense Management  Cheung Helen/C5273583
# 3                  HK_Business Planning Webinar CFOs  Cheung Helen/C5273583
# 4                               HK_CFO_webinar_helen  Cheung Helen/C5273583
# 5                       Sol_DSC_webinar_Ivy_20200407       Tan, Ivy/I344787
# 6                              CX_AR_webinar_sunqian               Sun Qian
# 7  HK_Nurture: Ariba Sourcing - IT + Supply Chain...  Cheung Helen/C5273583
# 8  HK_Nurture: Ariba Sourcing - Procurement & Fin...  Cheung Helen/C5273583
# 9         HK_Digital Workforce Webianr - SF + Concur  Cheung Helen/C5273583
#
# ...
