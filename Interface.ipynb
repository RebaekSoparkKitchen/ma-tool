# %%
# %run Exe.py
# Out:
# I import the third party module using 2.0636894702911377 seconds.
# I run this program using 0.14669299125671387 seconds.
# Future work
#                                         Campaign Name                 Owner   \
# 0                               CX_中国芯webinar_sunqian               Sun Qian
# 1                     HK_qualtrics visitor free trial  Cheung Helen/C5273583
# 2                    DG_SAP助您共克疫情 | 制造企业分析及建议_chenzhu               Zhu Chen
# 3                            CX_中国芯webinar_sunqian_W2               Sun Qian
# 4                   HK_Business Planning Webinar CFOs  Cheung Helen/C5273583
# 5                                HK_CFO_webinar_helen  Cheung Helen/C5273583
# 6                        Sol_DSC_webinar_Ivy_20200407       Tan, Ivy/I344787
# 7                               CX_AR_webinar_sunqian               Sun Qian
# 8   HK_Nurture: Ariba Sourcing - IT + Supply Chain...  Cheung Helen/C5273583
# ...
