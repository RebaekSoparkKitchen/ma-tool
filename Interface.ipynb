# %%
# %run Exe.py
# Out:
# I import the third party module using 0.0 seconds.
# I run this program using 0.12171101570129395 seconds.
# Future work
#                                        Campaign Name                 Owner   \
# 0                   HK_supply chain webinar_Helen_W2  Cheung Helen/C5273583
# 1                HK_Digitalist: We are here to help   Cheung Helen/C5273583
# 2                              GB_装饰行业_webinar_hulin             Hulin Zhou
# 3                              CX_中国芯webinar_sunqian               Sun Qian
# 4                   DG_SAP助您共克疫情 | 制造企业分析及建议_chenzhu               Zhu Chen
# 5                  HK_Business Planning Webinar CFOs  Cheung Helen/C5273583
# 6                               HK_CFO_webinar_helen  Cheung Helen/C5273583
# 7  HK_Nurture: Ariba Sourcing - IT + Supply Chain...  Cheung Helen/C5273583
# 8  HK_Nurture: Ariba Sourcing - Procurement & Fin...  Cheung Helen/C5273583
# 9         HK_Digital Workforce Webianr - SF + Concur  Cheung Helen/C5273583
#
# ...
