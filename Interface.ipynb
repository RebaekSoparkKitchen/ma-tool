# %%
# %run Exe.py
# Out:
# I import the third party module using 1.5534782409667969 seconds.
# I run this program using 0.15921616554260254 seconds.
# Future work
#                                  Campaign Name                 Owner   \
# 0                     GB_企业上市融资主题webinar_Apr28        Lily Li/I072293
# 1                    Sol_农林化工行业IBP webinar_Ivy       Tan, Ivy/I344787
# 2                  HK_Ariba Sourcing - Finance  Cheung Helen/C5273583
# 3                                Sol_SF年度峰会_W2    Sophie Quan/I054690
# 4                              CX_第三期邀请函_Apr28               Sun Qian
# 5                     GB_新能源行业webinar_apr22_W2                Jian Ma
# 6                               HK_AWS_webinar  Cheung Helen/C5273583
# 7   HK_Digital Workforce Webianr - SF + Concur  Cheung Helen/C5273583
# 8                    GB_企业出海主题webinar_Apr23_W2        Lily Li/I072293
# 9                  GB_企业上市融资主题webinar_Apr28_W2        Lily Li/I072293
# ...
